# %%
import pandas as pd

# %%
# %store -r animal1_df

# %%
animal1_df.head()
# Out:
#    Unnamed: 0           Animal Name   Kingdom    Phylum   Subphylum     Class  \
# 0           0           Arctic Wolf  Animalia  Chordata  Vertebrata  Mammalia
# 1           1            Arctic Fox  Animalia  Chordata  Vertebrata  Mammalia
# 2           2  Pink Fairy Armadillo  Animalia  Chordata  Vertebrata  Mammalia
# 3           3     Sumatran Elephant  Animalia  Chordata  Vertebrata  Mammalia
# 4           4                Ermine  Animalia  Chordata  Vertebrata  Mammalia
#
#   Subclass Infraclass        Order Superorder    Suborder Infraorder  \
# 0      NaN        NaN    Carnivora        NaN  Caniformia        NaN
# 1      NaN        NaN    Carnivora        NaN  Caniformia        NaN
# 2      NaN        NaN    Cingulata        NaN         NaN        NaN
# 3      NaN        NaN  Proboscidea        NaN         NaN        NaN
# 4      NaN        NaN    Carnivora        NaN  Caniformia        NaN
#
#            Family Superfamily       Subfamily         Genus Subgenus Tribe  \
# ...

# %%
animal1_df = animal1_df.drop(columns=["Unnamed: 0", "Kingdom", "Phylum", "Subphylum", "Class", "Subclass", "Infraclass", "Order", "Superorder", "Suborder", "Infraorder"])
animal1_df.head()
# Out:
#             Animal Name          Family Superfamily       Subfamily  \
# 0           Arctic Wolf         Canidae         NaN             NaN
# 1            Arctic Fox         Canidae         NaN             NaN
# 2  Pink Fairy Armadillo  Chlamyphoridae         NaN  Chlamyphorinae
# 3     Sumatran Elephant    Elephantidae         NaN             NaN
# 4                Ermine      Mustelidae         NaN      Mustelinae
#
#           Genus Subgenus Tribe Clade
# 0         Canis      NaN   NaN   NaN
# 1        Vulpes      NaN   NaN   NaN
# 2  Chlamyphorus      NaN   NaN   NaN
# 3       Elephas      NaN   NaN   NaN
# 4       Mustela      NaN   NaN   NaN

# %%
animal1_df = animal1_df.drop(columns=["Family", "Superfamily", "Subfamily", "Genus", "Subgenus", "Tribe", "Clade"])
animal1_df.head()
# Out:
#             Animal Name
# 0           Arctic Wolf
# 1            Arctic Fox
# 2  Pink Fairy Armadillo
# 3     Sumatran Elephant
# 4                Ermine

# %%
# %store animal1_df
# Out:
# Stored 'animal1_df' (DataFrame)

# %%
# %run snap-clean-words.ipynb
cleaned_animal1 = sepWords(animal1_df, "Animal Name")

# %%
cleaned_animal1.head()
# Out:
#     Words
# 0  Arctic
# 1    Wolf
# 2     Fox
# 3    Pink
# 4   Fairy

# %%
# %store cleaned_animal1
# Out:
# Stored 'cleaned_animal1' (DataFrame)
